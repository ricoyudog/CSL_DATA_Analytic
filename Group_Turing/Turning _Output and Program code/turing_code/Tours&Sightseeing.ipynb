# %%
import scrapy
from scrapy.crawler import CrawlerProcess
from scrapy import Request
import re
import pandas as pd

class ProductList(scrapy.Item):
    X1_product_code  =scrapy.Field()
    X2_product_category=scrapy.Field()
    X3_product_name = scrapy.Field()
    X4_product_rating= scrapy.Field()
    X5_product_oprice= scrapy.Field()
    X6_product_dprice= scrapy.Field()
    X7_website       = scrapy.Field()
    
#all_items
class go(scrapy.Spider):
    name='test2'
    allowed_domains=['www.klook.com/zh-HK']
    start_urls=['https://www.klook.com/zh-HK/search/?template_id=2&start={}&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3'.format(i+1)for i in range(4)]
    #start_urls=['https://www.klook.com/zh-HK/city/2-hong-kong/?city_id=2&limit=15&template_ids=&tag_ids=&instant=0&sort=&page={}'.format(i+1)for i in range(28)]
    ROBOTTXT_OBEY=False

    def start_requests(self):
        headers= {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36'}
        for url in self.start_urls:
            yield Request(url, headers=headers)  
    
    def parse(self,response):
        item = ProductList()
        target = response.css("div.m_justify_list.m_radius_box.act_card.act_card_sm.a_sd_move.j_activity_item.js-item ")
        for tag in target:
            
            website=tag.css("a.j_activity_item_link::attr(href)")[0].extract()
            item["X1_product_code"]=website[16:].split("-")[0]

            item["X2_product_category"]="一日遊&導賞團"
            
            
            
            try:
                product_name=tag.css("p.title::text")[0].extract()
                item["X3_product_name"]=product_name
            except:
                item["X3_product_name"]="NA"
            
            try:
                product_rating=tag.css("span.t14.star_score::text")[0].extract()
                item["X4_product_rating"]=product_rating
            except:
                item["X4_product_rating"]="NA"
            
            try:
                product_oprice=tag.css("p.del_price.u_t_gray_9 del::text")[0].extract().replace(" ","")
                item["X5_product_oprice"]=product_oprice
            except:
                item["X5_product_oprice"]="NA"
                
            try:
                product_dprice=tag.css("span.latest_price b::text")[0].extract().replace("HK$ ","").replace(" ","").replace("\n","")
                item["X6_product_dprice"]=product_dprice
            except:
                item["X6_product_dprice"]="NA"                            

            item["X7_website"]=("https://www.klook.com"+website)
            yield item

process = CrawlerProcess({
'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)',
'FEED_FORMAT': 'csv',
'FEED_URI': 'CHdata_Tours&Sightseeing.csv'
})
process.crawl(go)
process.start()
# Out:
# 2019-10-17 14:22:16 [scrapy.utils.log] INFO: Scrapy 1.7.3 started (bot: scrapybot)
# 2019-10-17 14:22:16 [scrapy.utils.log] INFO: Versions: lxml 4.3.4.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.7.0, Python 3.7.3 (default, Apr 24 2019, 15:29:51) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.7, Platform Windows-10-10.0.17763-SP0
# 2019-10-17 14:22:16 [scrapy.crawler] INFO: Overridden settings: {'FEED_FORMAT': 'csv', 'FEED_URI': 'CHdata_Tours&Sightseeing.csv', 'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2019-10-17 14:22:16 [scrapy.extensions.telnet] INFO: Telnet Password: 93599ceac8f01869
# 2019-10-17 14:22:16 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2019-10-17 14:22:17 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-10-17 14:22:17 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-10-17 14:22:17 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2019-10-17 14:22:17 [scrapy.core.engine] INFO: Spider opened
# 2019-10-17 14:22:17 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-10-17 14:22:17 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2019-10-17 14:22:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3> (referer: None)
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '5932',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '【私人包車遊】杭州市區',
#  'X4_product_rating': '4.0',
#  'X5_product_oprice': '700',
#  'X6_product_dprice': '669',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5932-private-car-charter-hangzhou/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '14896',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '杭州西湖與靈隱寺一日遊（飛來峰或三潭印月）',
#  'X4_product_rating': '4.8',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '374',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/14896-west-lake-lingying-temple-whole-day-tour-cruise-suzhou-hangzhou/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '16997',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': 'Wuzhen Old Street Full Day Tour with Lantern Evening '
#                     'Experience from Hangzhou',
#  'X4_product_rating': '4.5',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '517',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/16997-wuzhen-tour-lantern-experience-hangzhou/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '14927',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '莫干山文藝一日遊（杭州市區出發）',
#  'X4_product_rating': '4.7',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '440',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/14927-mount-mogan-whole-day-tour-suzhou-hangzhou/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '14875',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '杭州西湖一日遊',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '329',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/14875-west-lake-whole-day-tour-cruise-suzhou-hangzhou/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '8171',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '【私人包車遊】廣州現代景點',
#  'X4_product_rating': '3.5',
#  'X5_product_oprice': '528',
#  'X6_product_dprice': '445',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/8171-modern-guangzhou-half-day-private-transfer-guangdong/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '14942',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '【優惠來襲】慕田峪長城一日遊（含接送，北京出發）',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': '221',
#  'X6_product_dprice': '199',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/14942-mutianyu-great-wall-day-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '8136',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '【私人包車遊】廣州經典景點',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': '840',
#  'X6_product_dprice': '763',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/8136-guangzhou-one-day-private-transfer-to-historical-sites-guangdong/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '4018',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '上海觀光巴士',
#  'X4_product_rating': '4.1',
#  'X5_product_oprice': '111',
#  'X6_product_dprice': '98',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/4018-big-bus-sightseeing-tour-shanghai/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '3071',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '探訪文藝老上海',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': '847',
#  'X6_product_dprice': '796',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3071-literature-and-art-day-tour-shanghai/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '3076',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '探尋上海城市發展',
#  'X4_product_rating': '4.7',
#  'X5_product_oprice': '847',
#  'X6_product_dprice': '796',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3076-leisure-day-car-tour-Shanghai '
#                '/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '2046',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': 'ERA雜技表演（含接送）',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': '973',
#  'X6_product_dprice': '839',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/2046-era-acrobatics-show-shanghai/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '7658',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '【最高達8折優惠】包車遊覽 慕田峪長城遊覽',
#  'X4_product_rating': '4.5',
#  'X5_product_oprice': '201',
#  'X6_product_dprice': '165',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7658-mutianyu-great-wall-half-day-car-charter-beijing/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '2039',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '朝陽劇場雜技表演',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '275',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/2039-chaoyang-theatre-acrobatic-show-beijing/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '14956',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '司馬台長城 & 古北水鎮一日遊',
#  'X4_product_rating': '4.1',
#  'X5_product_oprice': '459',
#  'X6_product_dprice': '398',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/14956-simatai-great-wall-gubei-water-town-day-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '7586',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '北京故宮門票＋專業講解（私人導覽）',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': '367',
#  'X6_product_dprice': '330',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7586-the-forbidden-city-ticket-with-guide-beijing/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '1366',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '[Klook Exclusive: 20% Off] Complete Beijing Tour',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': '431',
#  'X6_product_dprice': '345',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/1366-complete-beijing-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '14947',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '八達嶺長城 & 定陵文物探尋之旅含接送（北京出發）',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': '252',
#  'X6_product_dprice': '239',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/14947-historical-sites-badaling-great-wall-ming-tombs-adventure-day-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '12983',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '上海朱家角水鄉古鎮 & 黃浦江夜景遊船',
#  'X4_product_rating': '4.2',
#  'X5_product_oprice': '730',
#  'X6_product_dprice': '426',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/12983-zhujiaojiao-ancient-water-town-tour-huangpu-river-night-cruise-shanghai/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '3042',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '北京文化展館一日遊',
#  'X4_product_rating': '4.8',
#  'X5_product_oprice': '829',
#  'X6_product_dprice': '685',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3042-capital-museum-chartered-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '7603',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '包車遊覽八達嶺長城半日遊覽',
#  'X4_product_rating': '4.1',
#  'X5_product_oprice': '343',
#  'X6_product_dprice': '309',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7603-badaaling-great-wall-half-day-chartering-beijing/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '14957',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '故宮 & 頤和園 & 天壇皇家探索之旅（含接送）',
#  'X4_product_rating': '4.0',
#  'X5_product_oprice': '437',
#  'X6_product_dprice': '381',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/14957-forbidden-city-summer-palace-temple-of-heaven-beijing/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '13514',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '西安歷史名勝一日遊（半坡＆秦始皇兵馬俑＆秦始皇陵）',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': '497',
#  'X6_product_dprice': '415',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/13514-ancient-chinese-culture-half-day-tour-xian/?krt=&krid='}
# 2019-10-17 14:22:17 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=1&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '9976',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '樂山地道美食 & 樂山大佛一日遊',
#  'X4_product_rating': '4.7',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '517',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/9976-leshan-giant-buddga-leshan-cuisine-day-tour-chengdu/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3> (referer: None)
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '7652',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '成都大熊貓基地＆杜甫草堂＆武侯祠私人導覽一日遊',
#  'X4_product_rating': '4.9',
#  'X5_product_oprice': '270',
#  'X6_product_dprice': '216',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7652-chengdu-panda-breeding-center-historic-private-day-tour/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '9771',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '漓江絕美景色深度遊覽一日遊',
#  'X4_product_rating': '4.8',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '517',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/9771-one-day-tour-in '
#                'Lijiang of Yangshuo/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '3054',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '什剎海休閒一日遊',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': '829',
#  'X6_product_dprice': '685',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3054-shichahai-one-day-trip-beijing/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '3072',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '上海熱門展館一日遊',
#  'X4_product_rating': '4.0',
#  'X5_product_oprice': '847',
#  'X6_product_dprice': '796',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3072-world-expo-permanent-exhibition-hall-shanghai/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '3053',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '北京古迹與現代建築導覽',
#  'X4_product_rating': '3.8',
#  'X5_product_oprice': '829',
#  'X6_product_dprice': '685',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3053-monuments-and-modern-architecture-chartered-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '5739',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '北京故宮 & 直升機遨遊八達嶺長城一日遊',
#  'X4_product_rating': '4.7',
#  'X5_product_oprice': '1,713',
#  'X6_product_dprice': '1,636',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5739-forbidden-city-badaling-sightseeing-helicopter-tour-beijing '
#                '/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '11550',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '重慶市內一日遊（長江索道 & 山城步道 & 李子壩 & 磁器口 & 兩江遊船）',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': '97',
#  'X6_product_dprice': '81',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11550-ticket-with-round-way-transfer-in-wulong-chongqing/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '3043',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '探尋北京名勝',
#  'X4_product_rating': '4.2',
#  'X5_product_oprice': '829',
#  'X6_product_dprice': '685',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3043-historical-sites-tour-Beijing '
#                '/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '5882',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '北京居庸關長城 & 十三陵一日遊',
#  'X4_product_rating': '4.5',
#  'X5_product_oprice': '862',
#  'X6_product_dprice': '718',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5882-juyonguan-great-wall-ming-tombs-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '3055',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '上海經典都市觀光一日遊',
#  'X4_product_rating': '4.8',
#  'X5_product_oprice': '847',
#  'X6_product_dprice': '796',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3055-classic-city-one-day-tour-Shanghai/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '7668',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '私人導覽遊覽都江堰 & 青城山',
#  'X4_product_rating': '4.9',
#  'X5_product_oprice': '270',
#  'X6_product_dprice': '230',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7668-private-day-tour-du-jiang-yan-mount-qin-cheng-cheng-du/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '5870',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '北京經典景點 & 品嘗全聚德烤鴨一日遊',
#  'X4_product_rating': '4.5',
#  'X5_product_oprice': '973',
#  'X6_product_dprice': '796',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5870-classic-attractions-tour-quanjude-duck-tasting-beijing/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '5860',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '北京天安門故宮 & 奧林匹克公園一日遊',
#  'X4_product_rating': '4.2',
#  'X5_product_oprice': '641',
#  'X6_product_dprice': '542',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5860-tiananmen-square-forbidden-city-olympic-park-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '7753',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '峨眉山私人導覽一日遊（成都出發）',
#  'X4_product_rating': '4.2',
#  'X5_product_oprice': '520',
#  'X6_product_dprice': '409',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7753-chengdu-mount-emei-scenic-area-private-day-tour/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '8147',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '【私人包車遊】廣州文化歷史景點',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': '840',
#  'X6_product_dprice': '763',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/8147-guangzhou-one-day-private-transfer-to-cultural-and-historical-sites-guangdong/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '5757',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '私人小團 天壇參觀 & 太極學習半日體驗',
#  'X4_product_rating': '4.8',
#  'X5_product_oprice': '365',
#  'X6_product_dprice': '271',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5757-temple-of-heaven-tai-chi-half-day-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '12146',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '小資情懷 上海瑰麗法租界半日步行導覽',
#  'X4_product_rating': '4.8',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '329',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/12146-shanghai-former-french-concession-walking-tour/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '12942',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '上海經典與現代全景觀光一日遊',
#  'X4_product_rating': '4.2',
#  'X5_product_oprice': '442',
#  'X6_product_dprice': '332',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/12942-classic-modern-sightseeing-tour-shanghai/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '12112',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '步行導覽 上海美租界半日深度遊',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '241',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/12112-shanghai-historical-concession-walking-tour-shanghai/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '15136',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '桂林龍脊梯田一日遊',
#  'X4_product_rating': '4.5',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '517',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/15136-longji-terraced-fields-one-day-tour-guilin/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '7707',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '私人導覽樂山大佛 & 品嚐樂山美食一日遊（成都出發）',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': '492',
#  'X6_product_dprice': '394',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7707-private-day-tour-cheng-du-to-le-shan-giant-buddha-and-enjoy-local-cuisine/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '9762',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '陽朔遇龍河騎行竹筏體驗一日遊',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '440',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/9762-yulong-river-bicycle-and-bamboo-raft-one-day-tour-guilin/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '7740',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '私人導覽漫遊成都人民公園',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': '116',
#  'X6_product_dprice': '99',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7740-private-half-day-tour-relax-like-a-local-cheng-du-people-s-park/?krt=&krid='}
# 2019-10-17 14:22:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=2&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '5699',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '北京直升機遨遊八達嶺長城 & 奧林匹克公園一日遊',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': '1,713',
#  'X6_product_dprice': '1,570',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5699-badaling-sightseeing-helicopter-olympic-park-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3> (referer: None)
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '8522',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '私人小團 大美麗江全景一日遊（虎跳峽 & 束河古鎮 & 長江第一灣 & 石鼓鎮）',
#  'X4_product_rating': '4.8',
#  'X5_product_oprice': '439',
#  'X6_product_dprice': '376',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/8522-private-lijiang-day-tour-yunnan/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '5808',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '私人小團 故宮參觀 & 太極學習一日體驗',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': '718',
#  'X6_product_dprice': '652',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5808-classic-attractions-tai-chi-full-day-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '9567',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '張家界國家公園&天子山一日遊（獨立成團）',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': '1,990',
#  'X6_product_dprice': '1,382',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/9567-private-zhangjiajie-national-park-tianzi-mountain-day-tour-zhangjiajie/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '12079',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '步行導覽上海豫園奇秀半日遊',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '361',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/12079-shanghai-city-walking-tour-shanghai/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '18989',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '都江堰深度一日遊（成都出發）',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '440',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/18989-mount-qingcheng-dujiangyan-day-tour-chengdu/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '10925',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '麗江古城一日探索 騎行之旅（納西石頭村 & 指雲寺 & 白沙古鎮 & 拉市海）',
#  'X4_product_rating': '4.0',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '296',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/10925-one-day-tour-looking-for-mysterious-lijiang-yunnan/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '8468',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '私人小團 昆明市區一日休閒遊（西山龍門 & 雲南省博物館 & 金馬碧雞坊 & 花鳥市場）',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': '439',
#  'X6_product_dprice': '345',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/8468-private-kunming-downtown-day-tour-yunnan/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '5894',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '靈渠門票',
#  'X4_product_rating': '4.8',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '61',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5894-ling-canal-ticket-guilin/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '7607',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '成都經典景點一日全覽（太古里& 成都博物館& 錦裡& 人民公園& 寬窄巷子）',
#  'X4_product_rating': '4.2',
#  'X5_product_oprice': '217',
#  'X6_product_dprice': '186',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7607-the-essence-of-cheng-du-city-china/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '9783',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '成都大熊貓繁育研究基地 & 人民公園一日遊',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '329',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/9783-chengdu-giant-panda-base-local-living-experience-chengdu/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '8478',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '私人小團大理精華一日遊（蒼山周城 & 喜洲嚴家大院 & 崇聖寺三塔 & 大理古城 & 洋人街）',
#  'X4_product_rating': '4.9',
#  'X5_product_oprice': '439',
#  'X6_product_dprice': '342',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/8478-private-dali-day-tour-yunnan/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '11017',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '沙溪古鎮深度慢體驗一日遊（大理/ 麗江出發可選）',
#  'X4_product_rating': '4.8',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '296',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11017-one-day-tour-in-shaxi-old-town-yunnan/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '11807',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '張家界天門山&土家風情園一日遊（獨立成團）',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': '1,769',
#  'X6_product_dprice': '1,448',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11807-private-tianmen-mountain-tujia-customs-park-day-tour-zhangjiajie/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '12090',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '上海楓涇古鎮半日遊',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '799',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/12090-fengjing-ancient-town-day-tour-shanghai/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '10953',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '大理洱海騎行深度遊+ 探秘喜洲古鎮一日遊',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '296',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/10953-tour-around-erhai-lake-by-bike-and-explore-xizhou-old-town-yunnan/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '11071',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '環瀘沽湖旅拍一日遊（乘坐Jeep 車型）',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '329',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11071-day-tour-photograph-in-lugu-lake-yunnan/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '11899',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '張家界大峽谷玻璃橋&寶峰湖一日遊（獨立成團）',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '1,769',
#  'X6_product_dprice': '1,589',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11899-private-zhangjiajie-grand-canyon-glass-bridge-baofeng-lake-day-tour-zhangjiajie/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '12184',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '步行導覽 上海印象蘇州河半日探索遊',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '241',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/12184-suzhou-river-walking-tour-shanghai '
#                '/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '14979',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '箭扣長城至慕田峪徒步之旅（含接送）',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '580',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/14979-jiankou-mutianyu-great-wall-day-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '17014',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '昆明全景一日遊（石林& 海埂大壩& 斗南花市& 地道美食）',
#  'X4_product_rating': '4.5',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '440',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/17014-dian-lake-flower-market-yunnan-roast-duck-kunming-stone-forest-1-day-tour-yunnan/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '17019',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': '悠涼撫仙湖一日遊（含登筆架山 & 尋觀音寺 & 遊船體驗）',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '329',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/17019-bijia-hill-guanyin-temple-cruise-cozy-fuxian-lake-1-day-tour-yunnan/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '18965',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': 'Nanshan Temple Day Tour in Sanya',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '473',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/18965-nanshan-temple-tour-sanya-haikou/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '19743',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': 'Guangdong Shunde Day Tour',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': '420',
#  'X6_product_dprice': '407',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/19743-shunde-day-tour-guangdong/?krt=&krid='}
# 2019-10-17 14:22:33 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=3&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '16836',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': 'Mount Hua Walking Day Tour',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': '741',
#  'X6_product_dprice': '663',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/16836-mount-hua-walking-day-tour-xian/?krt=&krid='}
# 2019-10-17 14:22:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.klook.com/zh-HK/search/?template_id=2&start=4&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3> (referer: None)
# 2019-10-17 14:22:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=4&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '16828',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': "Beijing Alleys, Beihai Park, and Prince Gong's Mansion "
#                     'Private Day Tour',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '1,879',
#  'X6_product_dprice': '1,795',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/16828-beihai-park-prince-gong-mansion-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=4&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '16831',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': 'Beijing Temple of Heaven and Traditional Food Private '
#                     'Half Day Tour',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '285',
#  'X6_product_dprice': '265',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/16831-temple-heaven-tianqiao-food-tour-beijing/?krt=&krid='}
# 2019-10-17 14:22:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=4&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '24131',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': 'Xi’an Highlights Day Tour',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': '661',
#  'X6_product_dprice': '591',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/24131-highlights-day-tour-xian/?krt=&krid='}
# 2019-10-17 14:22:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=4&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '24453',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': "Day Tour of Xi'an traditional art ",
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '403',
#  'X6_product_dprice': '359',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/24453-cultural-day-tour-xi-an/?krt=&krid='}
# 2019-10-17 14:22:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=4&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '24154',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': 'Xi’an Terracotta Warriors Half Day Tour',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '513',
#  'X6_product_dprice': '470',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/24154-terracotta-warriors-half-day-tour-xian/?krt=&krid='}
# 2019-10-17 14:22:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=4&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '27055',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': 'Downtown Beijing, New and Old Summer Palace Day Tour ',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '440',
#  'X6_product_dprice': '407',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/27055-beijing-downtown-summer-palace-day-tour/?krt=&krid='}
# 2019-10-17 14:22:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=4&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '27000',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': 'Mutianyu Great Wall and Beijing Local Day Tour',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '539',
#  'X6_product_dprice': '517',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/27000-mutianyu-great-wall-beijing-local-day-tour/?krt=&krid='}
# 2019-10-17 14:22:41 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=2&start=4&type=country&container_type=country&revamp_template_id=2&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=3>
# {'X1_product_code': '27056',
#  'X2_product_category': '一日遊&導賞團',
#  'X3_product_name': "Xi'an Terracotta Warriors and Mausoleum of the First Qin "
#                     'Emperor Tour ',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '407',
#  'X6_product_dprice': '374',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/27056-xian-terracotta-warriors-mausoleum-qin-emperor-day-tour/?krt=&krid='}
# 2019-10-17 14:22:41 [scrapy.core.engine] INFO: Closing spider (finished)
# 2019-10-17 14:22:41 [scrapy.extensions.feedexport] INFO: Stored csv feed (80 items) in: CHdata_Tours&Sightseeing.csv
# 2019-10-17 14:22:41 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1992,
#  'downloader/request_count': 4,
#  'downloader/request_method_count/GET': 4,
#  'downloader/response_bytes': 137343,
#  'downloader/response_count': 4,
#  'downloader/response_status_count/200': 4,
#  'elapsed_time_seconds': 24.419456,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2019, 10, 17, 6, 22, 41, 923284),
#  'item_scraped_count': 80,
#  'log_count/DEBUG': 84,
#  'log_count/INFO': 11,
#  'response_received_count': 4,
#  'scheduler/dequeued': 4,
#  'scheduler/dequeued/memory': 4,
#  'scheduler/enqueued': 4,
#  'scheduler/enqueued/memory': 4,
#  'start_time': datetime.datetime(2019, 10, 17, 6, 22, 17, 503828)}
# 2019-10-17 14:22:41 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
df=pd.read_csv("CHdata_Tours&Sightseeing.csv")
print(len(df))
# Out:
# 80
