# %%
#pip install prettyprint
#pip install googlemaps
import googlemaps
import pprint
import time
import pandas as pd

# %%
api_key = 'AIzaSyAzomxtqaHKyKknJoZwepqSCeOP9LRNlo4'

# %%
df=pd.read_csv('output/Final_Source/TW.csv')

# %%
product_names=list()
for i in df['Location']:
    product_names.append(i)
    print(i)
# Out:
# 太魯閣峽谷
# 花蓮縣
# 吉安慶修院
# 遠雄海洋公園
# 新光兆豐休閒農場
# 新社梯田
# 五股微風第四停車場集合
# 后豐鐵馬道
# 龍騰斷橋(魚藤坪斷橋)
# 清境農場
# 二鯤鯓砲臺(億載金城)
# 關子嶺溫泉
# 中正紀念堂
# 艋舺 鼎泰豐
# 野柳
# 三峽老街
# 陽明山公園
# 九份
# 佛光山佛陀紀念館
# 舊城
# 美濃民俗村
# 琉球嶼
# 禮納里
# OIA伊亞藝術咖啡館
# 恆春縣城 東門
# 猴探井天空之橋
# 恆春鎮大光里大光路79號之64
# 日月潭
# 屏東縣恆春鎮南灣里南灣路154號
# 906屏東縣高樹鄉尚和路12號
# 墾丁開放水域
# 屏東縣恆春鎮大光里大光路 118-5 號
# 屏東縣恆春鎮大光里大光路 118-5 號
# 10586, Taiwan, Taipei City, Songshan District, Jiankang Road, 408號1樓
# 國立海洋生物博物館
# 阿里山鄉
# 台灣最南點
# 墾丁國家公園
# 屏東縣琉球鄉中興路33-39號
# 秀姑巒溪
# 花蓮港
# 台灣地理中心碑虎頭山起飛場
# No. 21號, Kending Road, Hengchun Township, Pingtung County, Taiwan 946
# 延平教會
# 馥蘭朵烏
# 烏來露天溫泉
# 國立故宮博物院
# 台北市內湖區大湖街206號
# 台北101
# 太平山森林遊樂區
# 梅花湖
# 宜蘭文學館
# 冬山河親水公園
# 隘門金沙灘服務中心
# 七美望安跳島
# 浮潛秘境海底郵筒
# 澎湖海洋牧場
# 澎湖縣馬公市井仔垵16 - 2號
# 赤崁碼頭
# 澎湖縣湖西鄉湖西村173號
# 新北市金山區民生路1之2號
# 台東縣鹿野鄉永安村十三鄰中華路三段399號
# 屏東縣滿洲鄉茶山路457-10號（弔橋旁）
# 屏東縣恆春鎮大光路79-41號
# 老梅綠石槽
# 台北101觀景台
# 新北市淡水區淡海路280巷33弄36號
# 九份
# 臺北車站(忠孝)
# 九份
# 武陵農場
# 台北市內湖區大湖街206號
# 石碇千島湖
# 六福村主題遊樂園
# 杉林溪森林生態渡假園區
# 高美野生動物保護區
# 鹿港鎮
# 大湖酒莊
# 九族文化村
# 屏東縣恆春鎮南灣里南灣路728號
# ...

# %%
# Python program to get a set of 
# places according to your search 
# query using Google Places API 
latitude=list()
longtitude=list()
# importing required modules 
import requests, json 

# enter your api key here 
api_key = 'AIzaSyAzomxtqaHKyKknJoZwepqSCeOP9LRNlo4'

# url variable store url 
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"

# The text string on which to search 
for i in product_names:
    print(i)
    query =i
    r = requests.get(url + 'query=' + query +'&key=' + api_key) 
    x = r.json() 
    
    y = x['results'] 
    if y!=[]:
        for i in range(len(y)): 
            print(y[i]["geometry"]["location"]["lat"]) 
            latitude.append(y[i]["geometry"]["location"]["lat"])
            print(y[i]["geometry"]["location"]["lng"]) 
            longtitude.append(y[i]["geometry"]["location"]["lng"])
            print("===========================")
            break
    else:
        print("NA")
        print("===========================")

print("Done!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
# Print value corresponding to the 
# 'name' key at the ith index of y
# Out:
# 太魯閣峽谷
# 24.1731131
# 121.5453077
# ...
# 花蓮縣
# 23.9871589
# 121.6015714
# ...
# 吉安慶修院
# 23.9736882
# 121.5647145
# ...
# 遠雄海洋公園
# 23.9010106
# 121.601595
# ...
# 新光兆豐休閒農場
# 23.8020008
# 121.463043
# ...
# 新社梯田
# 23.65437
# 121.539429
# ...
# 五股微風第四停車場集合
# 25.0916803
# 121.4540583
# ...
# 后豐鐵馬道
# 24.2723042
# 120.7408254
# ...
# 龍騰斷橋(魚藤坪斷橋)
# 24.3584335
# 120.7738356
# ...
# 清境農場
# 24.0585107
# 121.1628284
# ...
# 二鯤鯓砲臺(億載金城)
# 22.987883
# 120.159255
# ...
# 關子嶺溫泉
# 23.3396518
# 120.50439
# ...
# 中正紀念堂
# 25.0346119
# 121.521781
# ...
# 艋舺 鼎泰豐
# 25.033483
# 121.530112
# ...
# 野柳
# 25.204757
# 121.6896172
# ...
# 三峽老街
# 24.9337605
# 121.3698182
# ...
# 陽明山公園
# 25.1942462
# 121.5609363
# ...
# 九份
# 25.109187
# 121.8462979
# ...
# 佛光山佛陀紀念館
# 22.7557018
# 120.4453197
# ...
# 舊城
# 22.6801384
# 120.2887721
# ...
# 美濃民俗村
# 22.8931271
# 120.5139777
# ...
# 琉球嶼
# 22.3404158
# 120.3715149
# ...
# 禮納里
# 22.7014333
# 120.6464532
# ...
# OIA伊亞藝術咖啡館
# 25.255245
# 121.474603
# ...
# 恆春縣城 東門
# 22.0040214
# 120.7501725
# ...
# 猴探井天空之橋
# 23.9084478
# 120.6315992
# ...
# 恆春鎮大光里大光路79號之64
# 21.9476319
# 120.7416521
# ...
# 日月潭
# 23.8573342
# 120.9159131
# ...

# %%
df['latitude'] = latitude
df['longtidue'] = longtitude
df.to_csv('output/Final_Source/TW_new.csv')

# %%
df
# Out:
#      X1_product_code                                    X3_product_name  \
# 0                419                                            太魯閣峽谷遊覽
# 1                420                                            花東縱谷一日遊
# 2                421                                          花蓮日式情懷半日遊
# 3                422                                        花蓮海洋主題樂園一日遊
# 4                423                                            兆豐農場一日遊
# 5                424                             東海岸之旅：新社海稻梯田（花蓮火車站出發）
# 6                436                                            滑水體驗與挑戰
# 7                440                                         后豐鐵馬道單車文化行
# 8                441                                          三義大甲雙城傳奇遊
# 9                444                                       清境農場 & 埔里一日遊
# 10               445                                             漫遊百年府城
# 11               447                                     關子嶺溫泉與土溝藝術村輕旅行
# ...
