# %%
import scrapy
from scrapy.crawler import CrawlerProcess
from scrapy import Request
import re
import pandas as pd

class ProductList(scrapy.Item):
    X1_product_code  =scrapy.Field()
    X2_product_category=scrapy.Field()
    X3_product_name = scrapy.Field()
    X4_product_rating= scrapy.Field()
    X5_product_oprice= scrapy.Field()
    X6_product_dprice= scrapy.Field()
    X7_website       = scrapy.Field()
    
#all_items
class go(scrapy.Spider):
    name='test2'
    allowed_domains=['www.klook.com/zh-HK']
    start_urls=['https://www.klook.com/zh-HK/search/?template_id=1&start={}&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2'.format(i+1)for i in range(5)]
    #start_urls=['https://www.klook.com/zh-HK/city/2-hong-kong/?city_id=2&limit=15&template_ids=&tag_ids=&instant=0&sort=&page={}'.format(i+1)for i in range(28)]
    ROBOTTXT_OBEY=False

    def start_requests(self):
        headers= {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36'}
        for url in self.start_urls:
            yield Request(url, headers=headers)  
    
    def parse(self,response):
        item = ProductList()
        target = response.css("div.m_justify_list.m_radius_box.act_card.act_card_sm.a_sd_move.j_activity_item.js-item ")
        for tag in target:
            
            website=tag.css("a.j_activity_item_link::attr(href)")[0].extract()
            item["X1_product_code"]=website[16:].split("-")[0]

            item["X2_product_category"]="景點門票&表演"
            
            
            
            try:
                product_name=tag.css("p.title::text")[0].extract()
                item["X3_product_name"]=product_name
            except:
                item["X3_product_name"]="NA"
            
            try:
                product_rating=tag.css("span.t14.star_score::text")[0].extract()
                item["X4_product_rating"]=product_rating
            except:
                item["X4_product_rating"]="NA"
            
            try:
                product_oprice=tag.css("p.del_price.u_t_gray_9 del::text")[0].extract().replace(" ","")
                item["X5_product_oprice"]=product_oprice
            except:
                item["X5_product_oprice"]="NA"
                
            try:
                product_dprice=tag.css("span.latest_price b::text")[0].extract().replace("HK$ ","").replace(" ","").replace("\n","")
                item["X6_product_dprice"]=product_dprice
            except:
                item["X6_product_dprice"]="NA"                            

            item["X7_website"]=("https://www.klook.com"+website)
            yield item

process = CrawlerProcess({
'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)',
'FEED_FORMAT': 'csv',
'FEED_URI': 'CHdata_Attractions&Shows.csv'
})
process.crawl(go)
process.start()
# Out:
# 2019-10-17 14:23:41 [scrapy.utils.log] INFO: Scrapy 1.7.3 started (bot: scrapybot)
# 2019-10-17 14:23:41 [scrapy.utils.log] INFO: Versions: lxml 4.3.4.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.7.0, Python 3.7.3 (default, Apr 24 2019, 15:29:51) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1c  28 May 2019), cryptography 2.7, Platform Windows-10-10.0.17763-SP0
# 2019-10-17 14:23:41 [scrapy.crawler] INFO: Overridden settings: {'FEED_FORMAT': 'csv', 'FEED_URI': 'CHdata_Attractions&Shows.csv', 'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2019-10-17 14:23:41 [scrapy.extensions.telnet] INFO: Telnet Password: 4e840eaaa2edd342
# 2019-10-17 14:23:41 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2019-10-17 14:23:41 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2019-10-17 14:23:41 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2019-10-17 14:23:41 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2019-10-17 14:23:41 [scrapy.core.engine] INFO: Spider opened
# 2019-10-17 14:23:42 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2019-10-17 14:23:42 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2019-10-17 14:23:42 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2> (referer: None)
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '5692',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '北京故宮紫禁城門票',
#  'X4_product_rating': '4.7',
#  'X5_product_oprice': '44',
#  'X6_product_dprice': '43',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5692-beijing-palace-museum-ticket-beijing/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '6602',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '張家界大峽谷套票（含玻璃吊橋）',
#  'X4_product_rating': '4.2',
#  'X5_product_oprice': '242',
#  'X6_product_dprice': '237',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/6602-grand-canyon-glass-bridge-tickets-zhangjiajie/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '6711',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '舟山桃花島風景區門票',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': '50',
#  'X6_product_dprice': '49',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/6711-zhoushan-taohua-island-hangzhou/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '4790',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '成都大熊貓繁育研究基地門票 - 掃描QR Code入園',
#  'X4_product_rating': '4.7',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '64',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/4790-giant-panda-breeding-research-base-ticket-chengdu/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '6613',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '天門山景區套票',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '285',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/6613-tianmen-mountain-cable-car-gallery-road-zhangjiajie/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '2128',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '上海迪士尼樂園門票',
#  'X4_product_rating': '4.7',
#  'X5_product_oprice': '441',
#  'X6_product_dprice': '419',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/2128-disney-resort-shanghai/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '8975',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '【特惠來襲】廣州長隆野生動物世界門票（中國籍遊客限定）',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '232',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/8975-guangzhou-chimelong-safari-park-guangdong/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '3172',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州長隆歡樂世界',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': '276',
#  'X6_product_dprice': '243',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3172-chimelong-paradise-guangzhou '
#                '/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '10497',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州塔觀光 & 珠江夜遊',
#  'X4_product_rating': '1.5',
#  'X5_product_oprice': '230',
#  'X6_product_dprice': '208',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/10497-canton-tower-sightseeing-pearl-river-night-cruise-guangdong/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '8972',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '【限時特惠】珠海長隆海洋王國（中國籍遊客限定）',
#  'X4_product_rating': '4.5',
#  'X5_product_oprice': '437',
#  'X6_product_dprice': '415',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/8972-chimelong-ocean-kingdom-park-for-mainland-china-guangdong/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '3106',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州長隆飛鳥樂園',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': '111',
#  'X6_product_dprice': '105',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3106-chimelong-bird-park-guangzhou/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '4382',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '朱家角古鎮 旅遊套票',
#  'X4_product_rating': '3.8',
#  'X5_product_oprice': '66',
#  'X6_product_dprice': '63',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/4382-zhujiajiao-ancient-town-combo-shanghai/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '9338',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '深圳錦繡中華民俗文化村門票',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': '230',
#  'X6_product_dprice': '220',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/9338-splendid-china-folk-village-ticket-guangdong/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '3157',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州百萬葵園門票',
#  'X4_product_rating': '3.2',
#  'X5_product_oprice': '166',
#  'X6_product_dprice': '149',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3157-sunflower-garden-guangzhou/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '9445',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州沙灣古鎮門票',
#  'X4_product_rating': '3.9',
#  'X5_product_oprice': '44',
#  'X6_product_dprice': '39',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/9445-shawan-town-guangzhou '
#                '/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '6722',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '寶峰湖景區套票',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': '134',
#  'X6_product_dprice': '117',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/6722-baofeng-lake-boat-ride-zhangjiajie/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '6365',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '上海ERA時空之旅雜技表演門票 - 享額外2%積分回饋',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '309',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/6365-era-intersection-of-time-acrobatic-show-ticket-shanghai/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '8977',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州長隆國際大馬戲門票（中國籍遊客限定）',
#  'X4_product_rating': '4.1',
#  'X5_product_oprice': '387',
#  'X6_product_dprice': '368',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/8977-guangzhou-chimelong-international-circus-guangdong/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '4333',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '上海中心大廈 上海之巔觀光廳（118層）',
#  'X4_product_rating': '4.5',
#  'X5_product_oprice': '199',
#  'X6_product_dprice': '182',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/4333-shanghai-tower-observation-deck-shanghai/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '3972',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '【限時75折優惠】金茂大廈88層觀光廳門票- 掃描QR Code直接入園',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': '133',
#  'X6_product_dprice': '97',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3972-jin-mao-tower-tickets-shanghai/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '3976',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '上海環球金融中心觀光廳',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': '199',
#  'X6_product_dprice': '171',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3976-world-financial-center-observation-deck-shanghai/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '6338',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '三亞千古情景區門票',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': '398',
#  'X6_product_dprice': '376',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/6338-sanya-romance-park-ticket-sanya/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '3973',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '黃浦江「清游江」遊覽船票',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': '133',
#  'X6_product_dprice': '116',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3973-hangpu-river-cruise-shanghai/?krt=&krid='}
# 2019-10-17 14:23:42 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=1&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '5902',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '象鼻山門票',
#  'X4_product_rating': '3.4',
#  'X5_product_oprice': '83',
#  'X6_product_dprice': '77',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5902-elephant-trunk-hill-ticket-guilin/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2> (referer: None)
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '6671',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '三亞天涯海角門票',
#  'X4_product_rating': '4.0',
#  'X5_product_oprice': '75',
#  'X6_product_dprice': '71',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/6671-tianya-haijiao-ticket-sanya/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '5898',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '蘆笛岩門票',
#  'X4_product_rating': '3.8',
#  'X5_product_oprice': '133',
#  'X6_product_dprice': '106',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5898-reed-flute-cave-ticket-guilin/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '3947',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '上海東方明珠塔 - 無需換票 掃碼入園',
#  'X4_product_rating': '4.2',
#  'X5_product_oprice': '216',
#  'X6_product_dprice': '210',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3947-oriental-pearl-tower-shanghai/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '2046',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': 'ERA雜技表演（含接送）',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': '973',
#  'X6_product_dprice': '839',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/2046-era-acrobatics-show-shanghai/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '3094',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州長隆野生動物世界',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': '332',
#  'X6_product_dprice': '325',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3094-chimelong-safari-park-guangzhou '
#                '/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '5955',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '秦始皇兵馬俑門票',
#  'X4_product_rating': '4.5',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '133',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5955-terracotta-army-ticket-xian/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '3114',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州長隆國際大馬戲',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': '387',
#  'X6_product_dprice': '368',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3114-chimelong-international-circus-guangzhou/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '3939',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '慕田峪長城門票及纜車票',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '50',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3939-mutianyu-great-wall-ticket-beijing/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '19013',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '上海迪士尼樂園門票 - 45天內預售票',
#  'X4_product_rating': '4.7',
#  'X5_product_oprice': '441',
#  'X6_product_dprice': '410',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/19013-disneyland-resort-ticket-shanghai/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '11454',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '上海迪士尼樂園門票（二日票）',
#  'X4_product_rating': '4.8',
#  'X5_product_oprice': '793',
#  'X6_product_dprice': '756',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11454-disney-resort-shanghai/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '23416',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州融創雪世界門票',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '199',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/23416-sunac-snow-park-admission-ticket-guangzhou/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '3340',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州長隆水上樂園門票',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': '221',
#  'X6_product_dprice': '210',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/3340-chimelong-waterpark-guangzhou/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '16738',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '上海豫園門票',
#  'X4_product_rating': '4.2',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '44',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/16738-yu-garden-admission-ticket-shanghai/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '5954',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '杭州《印象西湖—最憶是杭州》演出門票',
#  'X4_product_rating': '4.4',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '387',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5954-impression-west-lake-ticket-hangzhou/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '2039',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '朝陽劇場雜技表演',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '275',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/2039-chaoyang-theatre-acrobatic-show-beijing/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '10076',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '成都蜀風雅韻川劇表演門票',
#  'X4_product_rating': '4.5',
#  'X5_product_oprice': '265',
#  'X6_product_dprice': '166',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/10076-sichuan-opera-in-shufeng-yayung-garden-ticket-chengdu/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '7269',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '鷺江夜遊門票',
#  'X4_product_rating': '3.9',
#  'X5_product_oprice': '150',
#  'X6_product_dprice': '66',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7269-lujiang-river-night-cruise-xiamen/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '15514',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '【限時7折優惠】上海城市經典景點通票（含東方明珠、黃浦江等景點）',
#  'X4_product_rating': '3.5',
#  'X5_product_oprice': '486',
#  'X6_product_dprice': '330',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/15514-attraction-pass-shanghai/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '7272',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廈門日月谷溫泉門票',
#  'X4_product_rating': '4.8',
#  'X5_product_oprice': '252',
#  'X6_product_dprice': '208',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7272-riyuegu-hot-springs-xiamen/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '2030',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '梨園劇場京劇觀賞',
#  'X4_product_rating': '4.2',
#  'X5_product_oprice': '361',
#  'X6_product_dprice': '314',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/2030-peking-opera-liyuan-theater-beijing/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '23477',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州融創水世界門票',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': '252',
#  'X6_product_dprice': '199',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/23477- '
#                'sunac-water-world-admission-ticket-guangzhou/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '6733',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '上海東方明珠塔 & 黃浦江遊船套票',
#  'X4_product_rating': '3.4',
#  'X5_product_oprice': '343',
#  'X6_product_dprice': '260',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/6733-oriental-pearl-tower-huangpu-river-cruise-combo-ticket-shanghai/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '5903',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '桂林靖江王城 & 獨秀峰景區門票',
#  'X4_product_rating': '3.2',
#  'X5_product_oprice': '144',
#  'X6_product_dprice': '109',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5903-solitary-beauty-peak-jingjiang-princes-city-ticket-guilin/?krt=&krid='}
# 2019-10-17 14:23:47 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=2&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '17113',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '上海迪士尼音樂劇「美女與野獸」門票',
#  'X4_product_rating': '4.9',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '210',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/17113-beauty-beast-disney-musical-tickets-shanghai/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2> (referer: None)
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '4764',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '成都杜甫草堂博物館門票',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': '66',
#  'X6_product_dprice': '59',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/4764-dufu-thatched-cottage-ticket-chengdu/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '11507',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '重慶武隆景區一日遊（含往返接送 + 仙女山 / 天坑 / 地縫門票）',
#  'X4_product_rating': '4.7',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '118',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11507-ticket-with-round-way-transfer-in-wulong-chongqing/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '7840',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '上海迪士尼玩具總動員酒店一晚住宿',
#  'X4_product_rating': '4.8',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '2,023',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7840-toy-story-hotel-experience-one-night-shanghai/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '5909',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '桂林疊彩山公園 & 伏波山門票',
#  'X4_product_rating': '3.4',
#  'X5_product_oprice': '33',
#  'X6_product_dprice': '29',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5909-folded-brocade-hill-wave-subduing-hill-ticket-guilin/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '16702',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '【20分鐘確認】上海星空錯覺藝術館門票',
#  'X4_product_rating': '3.5',
#  'X5_product_oprice': '166',
#  'X6_product_dprice': '83',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/16702-star-illusion-art-gallery-ticket-shanghai/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '7164',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '昆明宜良九鄉風景區門票',
#  'X4_product_rating': '4.9',
#  'X5_product_oprice': '99',
#  'X6_product_dprice': '94',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7164-jiuxiang-scenic-region-kunming-yunnan/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '25408',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '珠海獅門娛樂天地門票',
#  'X4_product_rating': '3.4',
#  'X5_product_oprice': '193',
#  'X6_product_dprice': '182',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/25408-lionsgate-entertainment-world-ticket-zhuhai-guangdong/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '11550',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '重慶市內一日遊（長江索道 & 山城步道 & 李子壩 & 磁器口 & 兩江遊船）',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': '97',
#  'X6_product_dprice': '81',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11550-ticket-with-round-way-transfer-in-wulong-chongqing/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '4780',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '金沙遺址博物館門票',
#  'X4_product_rating': '4.7',
#  'X5_product_oprice': '88',
#  'X6_product_dprice': '83',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/4780-jinsha-site-museum-ticket-chengdu/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '2793',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '深圳歡樂谷門票 - 僅限中國大陸籍遊客',
#  'X4_product_rating': '4.7',
#  'X5_product_oprice': '254',
#  'X6_product_dprice': '243',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/2793-happy-valley-shenzhen/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '5923',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州越美冰雪大世界門票',
#  'X4_product_rating': '4.6',
#  'X5_product_oprice': '88',
#  'X6_product_dprice': '77',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5923-yuemei-ice-world-guangzhou-guangdong/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '5896',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '七星公園門票',
#  'X4_product_rating': '3.9',
#  'X5_product_oprice': '83',
#  'X6_product_dprice': '77',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5896-seven-star-park-ticket-guilin/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '7273',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '世茂雲上廈門觀光廳55層門票',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': '199',
#  'X6_product_dprice': '177',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7273-shimao-straits-tower-sightseeing-hall-xiamen/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '7259',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '鼓浪嶼貝殼夢幻世界門票',
#  'X4_product_rating': '3.8',
#  'X5_product_oprice': '86',
#  'X6_product_dprice': '53',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7259-gulangyu-seashell-museum-ticket-xiamen/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '5963',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '唐乾陵門票',
#  'X4_product_rating': '4.5',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '102',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5963-qianling-mausoleum-ticket-xian/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '7302',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廈門老院子民俗文化風情園& 「閩南傳奇」秀套票',
#  'X4_product_rating': '3.5',
#  'X5_product_oprice': '353',
#  'X6_product_dprice': '285',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7302-ancient-courtyard-folk-culture-garden-ticket-xiamen/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '6203',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '漢陽陵博物館門票',
#  'X4_product_rating': '3.8',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '72',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/6203-han-yang-ling-museum-ticket-xian/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '7258',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廈門「閩南神韻」演出門票',
#  'X4_product_rating': '3.7',
#  'X5_product_oprice': '199',
#  'X6_product_dprice': '149',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7258-minnan-magic-cultural-show-ticket-xiamen/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '2734',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州塔「小蠻腰」門票（中國大陸籍遊客限定）',
#  'X4_product_rating': '4.3',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '166',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/2734-canton-tower-guangzhou/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '9832',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '張家界「天門狐仙」演出門票',
#  'X4_product_rating': '3.0',
#  'X5_product_oprice': '296',
#  'X6_product_dprice': '208',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/9832-zhangjiajie-tianmen-fox-fairy-show-zhangjiajie/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '11855',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '重慶大足石刻門票 & 往返接送',
#  'X4_product_rating': '3.9',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '238',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11855-dazu-rock-carvings-ticket-round-trip-transfers-chongqing/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '23465',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州融創樂園門票',
#  'X4_product_rating': '4.7',
#  'X5_product_oprice': '285',
#  'X6_product_dprice': '252',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/23465-sunac-amusement-park-admission-ticket-guangzhou '
#                '/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '7492',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '高家大院門票',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '17',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7492-gao-grand-courtyard-ticket-xian/?krt=&krid='}
# 2019-10-17 14:23:55 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=3&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '7515',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '上海迪士尼樂園酒店一晚住宿',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '3,241',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7515-shanghai-disneyland-hotel-experience-one-night-shanghai/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2> (referer: None)
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '6687',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '張家界「魅力湘西」演出門票',
#  'X4_product_rating': '3.8',
#  'X5_product_oprice': '252',
#  'X6_product_dprice': '208',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/6687-charming-xiangxi-show-admission-ticket-zhangjiajie/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '5908',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '桂林銀子岩景區門票',
#  'X4_product_rating': '3.2',
#  'X5_product_oprice': '133',
#  'X6_product_dprice': '77',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5908-silver-cave-admission-ticket-guilin/?krt=&krid='}
# ...
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '貴州黃果樹瀑布門票（含交通）',
#  'X4_product_rating': '4.5',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '376',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11372-huangguoshu-waterfall-day-trip-roundtrip-transfers-guizhou/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '11660',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '深圳光明農場大觀園門票',
#  'X4_product_rating': '1.0',
#  'X5_product_oprice': '88',
#  'X6_product_dprice': '83',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11660-guangming-farm-adission-shenzhen/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '10921',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '中山幻彩摩天輪門票',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '75',
#  'X6_product_dprice': '66',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/10921-zhongshan-skywheel-ticket-guangdong/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '7418',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '黑山谷景區門票',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': '111',
#  'X6_product_dprice': '105',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7418-black-mountain-valley-chongqing/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '11479',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '西江千戶苗寨門票（含交通）',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '265',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11479-xijiang-qianhu-miao-village-day-trip-roundtrip-transfers-guizhou/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '5907',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '桂林陽朔蝴蝶泉景區門票',
#  'X4_product_rating': '3.8',
#  'X5_product_oprice': '61',
#  'X6_product_dprice': '55',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/5907-yangshuo-butterfly-spring-park-ticket-guilin/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '11465',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '貴州織金洞門票（含交通）',
#  'X4_product_rating': '4.0',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '282',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11465-zhijin-cave-ticket-roundtrip-transfers-guizhou/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '7494',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '黃帝陵景區門票',
#  'X4_product_rating': '4.8',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '78',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7494-huangdi-mausoleum-scenic-spot-ticket-xian/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '9588',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣東韶關乳源大峽谷門票',
#  'X4_product_rating': '4.0',
#  'X5_product_oprice': '72',
#  'X6_product_dprice': '66',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/9588-ruyuan-grand-canyon-ticket-guangdong/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '11772',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '清遠故鄉里主題公園門票',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '75',
#  'X6_product_dprice': '66',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11772-guxialngli-theme-park-admission-qingyuan-guangzhou/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '9851',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '湯山紫清湖旅遊區森林溫泉門票',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '242',
#  'X6_product_dprice': '221',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/9851-ziqinghu-hot-spring-ticket-nanjing/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '6851',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '南京周園門票',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '166',
#  'X6_product_dprice': '155',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/6851-zhouyuan-ticket-nanjing/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '7484',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '巫山小三峽遊覽套票',
#  'X4_product_rating': '4.7',
#  'X5_product_oprice': '166',
#  'X6_product_dprice': '159',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/7484-three-little-gorges-combo-ticket-chongqing/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '10267',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '廣州花都石頭記礦物園門票',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '66',
#  'X6_product_dprice': '53',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/10267-shitouji-mineral-park-ticket-guangzhou-guangdong/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '10531',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '茂名放雞島門票',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '199',
#  'X6_product_dprice': '177',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/10531-ticket-chicken-island-guangdong/?krt=&krid='}
# 2019-10-17 14:24:03 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=4&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '10566',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '清遠清泉灣漂流水城',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '141',
#  'X6_product_dprice': '99',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/10566-qingquan-bay-drifting-water-park-qingyuan-guangdong/?krt=&krid='}
# 2019-10-17 14:24:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.klook.com/zh-HK/search/?template_id=1&start=5&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2> (referer: None)
# 2019-10-17 14:24:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=5&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '11691',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '清遠連南千年瑤寨門票',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '108',
#  'X6_product_dprice': '94',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/11691-yao-nationality-village-nangang-ticket-guangdong/?krt=&krid='}
# 2019-10-17 14:24:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=5&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '12240',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '內蒙古神泉生態旅遊區門票',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '50',
#  'X6_product_dprice': '48',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/12240-shenquan-ecological-tourist-attraction-ticket-inner-mongolia/?krt=&krid='}
# 2019-10-17 14:24:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=5&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '12284',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '內蒙古道須溝景區門票',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '88',
#  'X6_product_dprice': '85',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/12284-daoxugou-scenic-spot-ticket-inner-mongolia/?krt=&krid='}
# 2019-10-17 14:24:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=5&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '12287',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '內蒙古額爾古納白樺林景區門票',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '57',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/12287-birch-tree-forest-scenic-area-ticket-inner-mongolia/?krt=&krid='}
# 2019-10-17 14:24:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=5&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '12290',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '內蒙古玉龍沙湖景區門票',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '88',
#  'X6_product_dprice': '86',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/12290-yulong-shahu-scenic-spot-ticket-inner-mongolia/?krt=&krid='}
# 2019-10-17 14:24:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=5&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '12318',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '內蒙古騰格里天鵝湖景區門票',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': 'NA',
#  'X6_product_dprice': '44',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/12318-tengger-swan-lake-ticket-inner-mongolia/?krt=&krid='}
# 2019-10-17 14:24:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=5&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '19871',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': 'DongTu Theater Acrobatic Show Ticket in Beijing',
#  'X4_product_rating': 'NA',
#  'X5_product_oprice': '199',
#  'X6_product_dprice': '144',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/19871-dongtu-acrobatic-show-ticket-beijing/?krt=&krid='}
# 2019-10-17 14:24:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=5&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '25610',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': '追光者——天才梵高深圳築夢大展門票',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': '208',
#  'X6_product_dprice': '175',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/25610-light-chaser-marvelous-exhibition-vincent-van-gogh-shenzhen/?krt=&krid='}
# 2019-10-17 14:24:11 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.klook.com/zh-HK/search/?template_id=1&start=5&type=country&container_type=country&revamp_template_id=1&revamp_city_id=105,57,59,58,288,60,61,62,161,174,177,179,182,184,187,256,257&revamp_country_id=20&revamp_index=2>
# {'X1_product_code': '23203',
#  'X2_product_category': '景點門票&表演',
#  'X3_product_name': 'Wuyishan Xiamei Ancient Village Admission Ticket',
#  'X4_product_rating': '5.0',
#  'X5_product_oprice': '66',
#  'X6_product_dprice': '61',
#  'X7_website': 'https://www.klook.com/zh-HK/activity/23203-wuyishan-xiamei-ancient-village-ticket-xiamen/?krt=&krid='}
# 2019-10-17 14:24:11 [scrapy.core.engine] INFO: Closing spider (finished)
# 2019-10-17 14:24:11 [scrapy.extensions.feedexport] INFO: Stored csv feed (105 items) in: CHdata_Attractions&Shows.csv
# 2019-10-17 14:24:11 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 2490,
#  'downloader/request_count': 5,
#  'downloader/request_method_count/GET': 5,
#  'downloader/response_bytes': 173342,
#  'downloader/response_count': 5,
#  'downloader/response_status_count/200': 5,
#  'elapsed_time_seconds': 29.164864,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2019, 10, 17, 6, 24, 11, 165155),
#  'item_scraped_count': 105,
#  'log_count/DEBUG': 110,
#  'log_count/INFO': 11,
#  'response_received_count': 5,
#  'scheduler/dequeued': 5,
#  'scheduler/dequeued/memory': 5,
#  'scheduler/enqueued': 5,
#  'scheduler/enqueued/memory': 5,
#  'start_time': datetime.datetime(2019, 10, 17, 6, 23, 42, 291)}
# 2019-10-17 14:24:11 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import pandas as pd
df=pd.read_csv("CHdata_Attractions&Shows.csv")
print(len(df))
# Out:
# 105
